# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdirahmanMoualem29/Crop-Yield-Prediction-ML/blob/main/Weathercode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5be8b39d-7f77-4ea2-8420-b7af60c7abb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5be8b39d-7f77-4ea2-8420-b7af60c7abb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Assuming the uploaded file name is 'your_file_name.csv'
weather = pd.read_csv("John Glenn Airport.csv", index_col = "DATE")

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
valid_columns = weather.columns[null_pct < 0.05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather
# Out:
#                STATION                                     NAME  PRCP  SNOW  \
# DATE
# 1/1/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.14   2.2
# 1/2/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.06   1.5
# 1/3/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.04   0.7
# 1/4/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.01   0.3
# 1/5/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.2
# ...                ...                                      ...   ...   ...
# 9/10/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/11/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/12/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.21   0.0
# 9/13/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/14/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
#
#            SNWD  TMAX  TMIN
# DATE
# ...

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                station                                     name  prcp  snow  \
# DATE
# 1/1/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.14   2.2
# 1/2/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.06   1.5
# 1/3/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.04   0.7
# 1/4/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.01   0.3
# 1/5/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.2
# ...                ...                                      ...   ...   ...
# 9/10/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/11/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/12/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.21   0.0
# 9/13/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/14/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
#
#            snwd  tmax  tmin
# DATE
# ...

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather
# Out:
#                station                                     name  prcp  snow  \
# DATE
# 1/1/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.14   2.2
# 1/2/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.06   1.5
# 1/3/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.04   0.7
# 1/4/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.01   0.3
# 1/5/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.2
# ...                ...                                      ...   ...   ...
# 9/10/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/11/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/12/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.21   0.0
# 9/13/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/14/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
#
#            snwd  tmax  tmin
# DATE
# ...

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                station                                     name  prcp  snow  \
# DATE
# 1/1/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.14   2.2
# 1/2/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.06   1.5
# 1/3/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.04   0.7
# 1/4/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.01   0.3
# 1/5/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.2
# ...                ...                                      ...   ...   ...
# 9/10/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/11/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/12/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.21   0.0
# 9/13/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/14/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
#
#            snwd  tmax  tmin  target
# DATE
# ...

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                station                                     name  prcp  snow  \
# DATE
# 1/1/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.14   2.2
# 1/2/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.06   1.5
# 1/3/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.04   0.7
# 1/4/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.01   0.3
# 1/5/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.2
# ...                ...                                      ...   ...   ...
# 9/10/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/11/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/12/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.21   0.0
# 9/13/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/14/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
#
#            snwd  tmax  tmin  target
# DATE
# ...

# %%
""" Linear regression is about finding the best fit line/plane for the data.
 Ridge regression does the same but with a penalty to avoid overly complex models and large coefficients. """
from sklearn.linear_model import Ridge
# the alpha parameter controls how much the coefficients are shrunk to account for collinearity
rr = Ridge(alpha=.1)

# %%
weather
# Out:
#                station                                     name  prcp  snow  \
# DATE
# 1/1/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.14   2.2
# 1/2/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.06   1.5
# 1/3/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.04   0.7
# 1/4/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.01   0.3
# 1/5/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.2
# ...                ...                                      ...   ...   ...
# 9/10/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/11/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/12/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.21   0.0
# 9/13/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/14/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
#
#            snwd  tmax  tmin  target
# DATE
# ...

# %%
## negate unneeded data (~ is the negate operator for python)
predictors = weather.columns[~weather.columns.isin(["name","target","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rolling_3_tmax',
#        'rolling_3_tmax_pct', 'rolling_3_tmin', 'rolling_3_tmin_pct',
#        'rolling_3_prcp', 'rolling_3_prcp_pct', 'rolling_14_tmax',
#        'rolling_14_tmax_pct', 'rolling_14_tmin', 'rolling_14_tmin_pct',
#        'rolling_14_prcp', 'rolling_14_prcp_pct', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp'],
#       dtype='object')

# %%
'''To assess a machine learning model's error, use cross-validation. For time series data, employ time series cross-validation to
 avoid predicting the past using future data.'''

def backtest(weather, model, predictors, start=3650, step=90):
  all_predictions = []  # List to store prediction results for each test window

    # Looping through the data in steps, starting from 'start' index
  for i in range(start, weather.shape[0], step):

        # Splitting data into training and testing sets
        train = weather.iloc[:i, :]
        test = weather.iloc[i:(i+step), :]

        # Training the model
        model.fit(train[predictors], train["target"])

        # Making predictions on the test set
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)

        # Combining actual and predicted values
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]

        # Calculating absolute differences between predictions and actual values
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()

        # Storing the results
        all_predictions.append(combined)

    # Combining all prediction results into a single DataFrame
  return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr,predictors)

# %%
predictions
# Out:
#             actual  prediction      diff
# DATE
# 12/30/1979    30.0   35.321431  5.321431
# 12/31/1979    32.0   35.284555  3.284555
# 1/1/1980      31.0   37.641168  6.641168
# 1/2/1980      33.0   36.710790  3.710790
# 1/3/1980      31.0   38.062667  7.062667
# ...            ...         ...       ...
# 9/10/2023     81.0   78.657580  2.342420
# 9/11/2023     70.0   79.488554  9.488554
# 9/12/2023     74.0   70.923854  3.076146
# 9/13/2023     75.0   74.116433  0.883567
# 9/14/2023     75.0   73.996330  1.003670
#
# [15965 rows x 3 columns]

# %%
# this is us to get the prection error in are code
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.953735532402025

# %%
from numpy.core.fromnumeric import mean
# look at th averge for the last couple to get better acuracy
def pct_diff(old, new):
  return (new-old)/old
# horizon is the average
def compute_rolling(weather, horizon, col):
  # label is a string for the columns
  label = f"rolling_{horizon}_{col}"
  # create a labe to get the averge rolling day in the couple past days
  weather[label] = weather[col].rolling(horizon).mean()
  # find the percntege difference between the rolling and today: base first
  # and colum second
  weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
  return weather
# first average the last three days and then average the last 14 days
rolling_horizons = [3,14]
## the horizon is how many days it averages
for horizon in rolling_horizons:
  for col in["tmax","tmin","prcp"]:
    weather = compute_rolling(weather, horizon,col)

# %%
weather
# Out:
#                station                                     name  prcp  snow  \
# DATE
# 1/1/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.14   2.2
# 1/2/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.06   1.5
# 1/3/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.04   0.7
# 1/4/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.01   0.3
# 1/5/1970   USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.2
# ...                ...                                      ...   ...   ...
# 9/10/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/11/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/12/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.21   0.0
# 9/13/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/14/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
#
# ...

# %%
#this remove the first 14 columns , loc remove the days
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                station                                     name  prcp  snow  \
# DATE
# 1/15/1970  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1/16/1970  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1/17/1970  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1/18/1970  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.03   0.1
# 1/19/1970  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.02   0.5
# ...                ...                                      ...   ...   ...
# 9/10/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/11/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/12/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.21   0.0
# 9/13/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 9/14/2023  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
#
# ...

# %%
## fills in the all empty
weather = weather.fillna(0)

# %%
# Check if the index is not a DatetimeIndex
if not isinstance(weather.index, pd.DatetimeIndex):
    # Convert the index to a DatetimeIndex
    weather.index = pd.to_datetime(weather.index)

# %%
## add more predictors: expand mean - take dataframe as input
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                                     name  prcp  snow  \
# DATE
# 1970-01-15  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1970-01-16  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1970-01-17  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1970-01-18  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.03   0.1
# 1970-01-19  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.02   0.5
# ...                 ...                                      ...   ...   ...
# 2023-09-10  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 2023-09-11  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 2023-09-12  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.21   0.0
# 2023-09-13  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 2023-09-14  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
#
# ...

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rolling_3_tmax',
#        'rolling_3_tmax_pct', 'rolling_3_tmin', 'rolling_3_tmin_pct',
#        'rolling_3_prcp', 'rolling_3_prcp_pct', 'rolling_14_tmax',
#        'rolling_14_tmax_pct', 'rolling_14_tmin', 'rolling_14_tmin_pct',
#        'rolling_14_prcp', 'rolling_14_prcp_pct', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp'],
#       dtype='object')

# %%
# Filter only numeric columns
numeric_weather = weather.select_dtypes(include=[np.number])

# %%
if not np.isfinite(numeric_weather).all().all():
    # Replace infinite values with NaN in the original DataFrame
    weather.replace([np.inf, -np.inf], np.nan, inplace=True)

    # Optional: Handle NaN values, e.g., using forward fill
    # weather.fillna(method='ffill', inplace=True)

# %%
print(weather.isnull().sum())
# Out:
# station                0
# name                   0
# prcp                   0
# snow                   0
# snwd                   0
# tmax                   0
# tmin                   0
# target                 0
# rolling_3_tmax         0
# rolling_3_tmax_pct     0
# rolling_3_tmin         0
# rolling_3_tmin_pct     8
# rolling_3_prcp         0
# rolling_3_prcp_pct     0
# rolling_14_tmax        0
# rolling_14_tmax_pct    0
# rolling_14_tmin        0
# rolling_14_tmin_pct    0
# rolling_14_prcp        0
# rolling_14_prcp_pct    0
# month_avg_tmax         0
# day_avg_tmax           0
# month_avg_tmin         0
# day_avg_tmin           0
# month_avg_prcp         0
# day_avg_prcp           0
# dtype: int64

# %%
null_rows = weather.loc[weather['rolling_3_tmin_pct'].isnull()]
print(null_rows)
# Out:
# Empty DataFrame
# Columns: [station, name, prcp, snow, snwd, tmax, tmin, target, rolling_3_tmax, rolling_3_tmax_pct, rolling_3_tmin, rolling_3_tmin_pct, rolling_3_prcp, rolling_3_prcp_pct, rolling_14_tmax, rolling_14_tmax_pct, rolling_14_tmin, rolling_14_tmin_pct, rolling_14_prcp, rolling_14_prcp_pct, month_avg_tmax, day_avg_tmax, month_avg_tmin, day_avg_tmin, month_avg_prcp, day_avg_prcp]
# Index: []
#
# [0 rows x 26 columns]

# %%
weather['rolling_3_tmin_pct'].fillna(weather['rolling_3_tmin_pct'].median(), inplace=True)

# %%
predictions = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.533690458633543

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1980-01-13    41.0   40.492142   0.507858
# 1980-01-14    39.0   40.630354   1.630354
# 1980-01-15    52.0   40.725704  11.274296
# 1980-01-16    57.0   47.595948   9.404052
# 1980-01-17    39.0   47.366615   8.366615
# ...            ...         ...        ...
# 2023-09-10    81.0   80.032648   0.967352
# 2023-09-11    70.0   80.365716  10.365716
# 2023-09-12    74.0   68.591396   5.408604
# 2023-09-13    75.0   77.500179   2.500179
# 2023-09-14    75.0   77.405746   2.405746
#
# [15951 rows x 3 columns]

# %%
# how to check what happen in a year for error
weather.loc["1980-01-10": "1980-01-17"]
# Out:
#                 station                                     name  prcp  snow  \
# DATE
# 1980-01-10  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1980-01-11  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  1.02   0.0
# 1980-01-12  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1980-01-13  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1980-01-14  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.03   0.0
# 1980-01-15  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1980-01-16  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.00   0.0
# 1980-01-17  USW00014821  JOHN GLENN INTERNATIONAL AIRPORT, OH US  0.01   0.0
#
#             snwd  tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  ...  \
# DATE                                                                      ...
# 1980-01-10   0.0  44.0  18.0    55.0       33.000000            0.333333  ...
# ...

# %%
## it show how many time are error was off predcting
predictions["diff"].round().value_counts().sort_index()
# Out:
# 0.0      951
# 1.0     1873
# 2.0     1867
# 3.0     1736
# 4.0     1578
# 5.0     1432
# 6.0     1226
# 7.0     1038
# 8.0      882
# 9.0      675
# 10.0     529
# 11.0     450
# 12.0     388
# 13.0     295
# 14.0     246
# 15.0     199
# 16.0     148
# 17.0     106
# 18.0      83
# 19.0      74
# 20.0      43
# 21.0      45
# 22.0      27
# 23.0      19
# 24.0      14
# 25.0       6
# 26.0       4
# 27.0       5
# 28.0       3
# 29.0       4
# 30.0       2
# 32.0       1
# 33.0       1
# 34.0       1
# Name: diff, dtype: int64

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: >
