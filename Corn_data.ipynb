# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdirahmanMoualem29/Crop-Yield-Prediction-ML/blob/main/Corn_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-088d7679-2b13-4f39-aafc-99f7352cad59" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-088d7679-2b13-4f39-aafc-99f7352cad59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Assuming the uploaded file name is 'your_file_name.csv'
corn = pd.read_csv("A7C3C9F8-DE61-36FB-87DD-873467B1239F.csv", index_col = "Week Ending")

# %%
corn
# Out:
#             Program  Year    Period Geo Level State  State ANSI  Ag District  \
# Week Ending
# 2023-04-02   SURVEY  2023  WEEK #13     STATE  OHIO          39          NaN
# 2023-04-09   SURVEY  2023  WEEK #14     STATE  OHIO          39          NaN
# 2023-04-16   SURVEY  2023  WEEK #15     STATE  OHIO          39          NaN
# 2023-04-23   SURVEY  2023  WEEK #16     STATE  OHIO          39          NaN
# 2023-04-23   SURVEY  2023  WEEK #16     STATE  OHIO          39          NaN
# ...             ...   ...       ...       ...   ...         ...          ...
# 2000-05-14   SURVEY  2000  WEEK #19     STATE  OHIO          39          NaN
# 2000-05-21   SURVEY  2000  WEEK #20     STATE  OHIO          39          NaN
# 2000-05-21   SURVEY  2000  WEEK #20     STATE  OHIO          39          NaN
# 2000-05-28   SURVEY  2000  WEEK #21     STATE  OHIO          39          NaN
# 2000-06-04   SURVEY  2000  WEEK #22     STATE  OHIO          39          NaN
#
# ...

# %%
null_pct = corn.apply(pd.isnull).sum()/corn.shape[0]

# %%
null_pct
# Out:
# Program             0.0
# Year                0.0
# Period              0.0
# Geo Level           0.0
# State               0.0
# State ANSI          0.0
# Ag District         1.0
# Ag District Code    1.0
# County              1.0
# County ANSI         1.0
# Zip Code            1.0
# Region              1.0
# watershed_code      0.0
# Watershed           1.0
# Commodity           0.0
# Data Item           0.0
# Domain              0.0
# Domain Category     0.0
# Value               0.0
# CV (%)              1.0
# dtype: float64

# %%
valid_columns = corn.columns[null_pct < 0.05]

# %%
valid_columns
# Out:
# Index(['Program', 'Year', 'Period', 'Geo Level', 'State', 'State ANSI',
#        'watershed_code', 'Commodity', 'Data Item', 'Domain', 'Domain Category',
#        'Value'],
#       dtype='object')

# %%
corn.columns = corn.columns.str.lower()

# %%
corn.apply(pd.isnull).sum()
# Out:
# program               0
# year                  0
# period                0
# geo level             0
# state                 0
# state ansi            0
# ag district         432
# ag district code    432
# county              432
# county ansi         432
# zip code            432
# region              432
# watershed_code        0
# watershed           432
# commodity             0
# data item             0
# domain                0
# domain category       0
# value                 0
# cv (%)              432
# dtype: int64

# %%
corn.dtypes
# Out:
# program              object
# year                  int64
# period               object
# geo level            object
# state                object
# state ansi            int64
# ag district         float64
# ag district code    float64
# county              float64
# county ansi         float64
# zip code            float64
# region              float64
# watershed_code        int64
# watershed           float64
# commodity            object
# data item            object
# domain               object
# domain category      object
# value                 int64
# cv (%)              float64
# dtype: object

# %%
corn.year = pd.to_datetime(corn.year)

# %%
corn.year
# Out:
# Week Ending
# 2023-04-02   1970-01-01 00:00:00.000002023
# 2023-04-09   1970-01-01 00:00:00.000002023
# 2023-04-16   1970-01-01 00:00:00.000002023
# 2023-04-23   1970-01-01 00:00:00.000002023
# 2023-04-23   1970-01-01 00:00:00.000002023
#                           ...
# 2000-05-14   1970-01-01 00:00:00.000002000
# 2000-05-21   1970-01-01 00:00:00.000002000
# 2000-05-21   1970-01-01 00:00:00.000002000
# 2000-05-28   1970-01-01 00:00:00.000002000
# 2000-06-04   1970-01-01 00:00:00.000002000
# Name: year, Length: 432, dtype: datetime64[ns]

# %%
corn['year'].dt.year.value_counts().sort_index()
# Out:
# 1970    432
# Name: year, dtype: int64

# %%
print(corn.columns)
# Out:
# Index(['program', 'year', 'period', 'geo level', 'state', 'state ansi',
#        'ag district', 'ag district code', 'county', 'county ansi', 'zip code',
#        'region', 'watershed_code', 'watershed', 'commodity', 'data item',
#        'domain', 'domain category', 'value', 'cv (%)'],
#       dtype='object')

# %%
corn['value'].plot()
# Out:
# <Axes: xlabel='Week Ending'>
